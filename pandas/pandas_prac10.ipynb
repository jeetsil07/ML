# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\datasets\weather_melt.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df1 = pd.melt(df, id_vars=['day'],var_name='city',val_name='temperature')
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1 = pd.melt(df, id_vars=['day'],var_name='city',val_name='temperature')
#       2 df1
#
# TypeError: melt() got an unexpected keyword argument 'val_name'
