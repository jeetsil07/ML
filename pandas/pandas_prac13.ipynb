# %%
# !pip install pymysql

# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:root@localhost:3307/pandas")

# %%
df = pd.read_sql_table("customers", engine, columns=['name', 'phone_number'])

print(df)
# Out:
#      name phone_number
# 0  Donald   9876543210
# 1    Bill   9123456780
# 2    Modi   9988776655

# %%
df = pd.read_sql("SELECT name, phone_number FROM customers", engine)

print(df)
# Out:
#      name phone_number
# 0  Donald   9876543210
# 1    Bill   9123456780
# 2    Modi   9988776655

# %%
query = '''
SELECT customers.name,customers.phone_number,orders.name,orders.amount
FROM customers INNER JOIN orders
ON customers.id = orders.customer_id
'''
df = pd.read_sql_query(query,engine)
df
# Out:
#      name phone_number          name  amount
# 0  Donald   9876543210  Google Pixel   950.0
# 1    Bill   9123456780      Yoga Mat    20.0
# 2    Modi   9988776655  Fossil Watch   120.0

# %%
df = pd.DataFrame({
    'Customer Name': ['Jeet Sil', 'Jhony Dep'],
    'Customer Phone': ['789010401','8794567589']
})
df
# Out:
#   Customer Name Customer Phone
# 0      Jeet Sil      789010401
# 1     Jhony Dep     8794567589

# %%
df.rename(columns={
    'Customer Name': 'name',
    'Customer Phone': 'phone_number'
},inplace=True)
df
# Out:
#         name phone_number
# 0   Jeet Sil    789010401
# 1  Jhony Dep   8794567589

# %%
df.to_sql(
    name='customers',
    con=engine,
    index= False,
    if_exists='append'
)
# Out:
# 2
