# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\machine_learning_practice\supervise_learning\linear_reg\datasets\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price, marker='+',c='red')
plt.plot(df.area,reg.predict(df[['area']]), c ='blue')
plt.show()

# %%
new_df = df.drop('price', axis="columns")
new_df
new_df.shape
# Out:
# (5, 1)

# %%
price= df.price
price
price.shape
# Out:
# (5,)

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[3333]])
# Out:
# C:\Users\Jeet\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([633196.74657534])

# %%
area_df = pd.read_csv(r"E:\machine_learning_practice\supervise_learning\linear_reg\datasets\areas.csv")
prices = reg.predict(area_df)
print(prices)
# Out:
# [ 316404.10958904  384297.94520548  492928.08219178  661304.79452055
#   740061.64383562  799808.21917808  926090.75342466  650441.78082192
#   825607.87671233  492928.08219178 1402705.47945205 1348390.4109589
#  1144708.90410959]

# %%
area_df['price'] = prices
area_df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv(r"E:\machine_learning_practice\supervise_learning\linear_reg\datasets\predicted_area_prices.csv",index=False)
