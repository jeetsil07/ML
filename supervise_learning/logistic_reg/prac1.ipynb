# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\machine_learning_practice\supervise_learning\logistic_reg\datasets\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance, c='red',marker='+')
plt.xlabel('age')
plt.ylabel('bought_insurance')
# Out:
# Text(0, 0.5, 'bought_insurance')

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance, train_size=0.8)
X_test
# Out:
#     age
# 5    56
# 15   55
# 9    61
# 10   18
# 20   21
# 19   18

# %%
reg = LogisticRegression()
reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
reg.predict([[78]])
# Out:
# C:\Users\Jeet\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
reg.predict([[17]])
# Out:
# C:\Users\Jeet\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
reg.predict(X_test)
# Out:
# array([1, 1, 1, 0, 0, 0], dtype=int64)

# %%
reg.predict_proba(X_test)
# Out:
# array([[0.11860149, 0.88139851],
#        [0.1313993 , 0.8686007 ],
#        [0.06970489, 0.93029511],
#        [0.92012066, 0.07987934],
#        [0.89019096, 0.10980904],
#        [0.92012066, 0.07987934]])
